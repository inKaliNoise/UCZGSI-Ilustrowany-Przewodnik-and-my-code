# %% [markdown]
# # Głęboka sieć w Keras

# %% [markdown]
# W tym notatniku usprawniamy poprzednią, płytką sieć, wykorzystując poznaną dotychczas teorię.

# %% [markdown]
# #### Załadowanie zależności.

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout # Nowość!
from keras.layers.normalization import BatchNormalization # Nowość!
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Załadowanie danych.

# %%
(X_train, y_train), (X_valid, y_valid) = mnist.load_data()

# %% [markdown]
# #### Wstępne przetworzenie danych.

# %%
X_train = X_train.reshape(60000, 784).astype('float32')
X_valid = X_valid.reshape(10000, 784).astype('float32')

# %%
X_train /= 255
X_valid /= 255

# %%
n_classes = 10
y_train = keras.utils.to_categorical(y_train, n_classes)
y_valid = keras.utils.to_categorical(y_valid, n_classes)

# %% [markdown]
# #### Architektura sieci neuronowej.

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 64)                50240
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# ...

# %% [markdown]
# #### Konfiguracja modelu.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #### Trening!

# %%
model.fit(X_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(X_valid, y_valid))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.3717 - acc: 0.8896 - val_loss: 0.1522 - val_acc: 0.9518
# Epoch 2/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1500 - acc: 0.9544 - val_loss: 0.1191 - val_acc: 0.9619
# Epoch 3/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1121 - acc: 0.9655 - val_loss: 0.1055 - val_acc: 0.9670
# Epoch 4/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0907 - acc: 0.9722 - val_loss: 0.0929 - val_acc: 0.9712
# Epoch 5/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0754 - acc: 0.9769 - val_loss: 0.1001 - val_acc: 0.9698
# Epoch 6/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0640 - acc: 0.9803 - val_loss: 0.0883 - val_acc: 0.9723
# Epoch 7/20
# ...
