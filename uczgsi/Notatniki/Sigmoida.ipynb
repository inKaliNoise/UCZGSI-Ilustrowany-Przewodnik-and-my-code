# %% [markdown]
# # Sigmoida

# %%
from math import e

# %%
def sigmoid(z):
    return 1/(1+e**-z)

# %%
sigmoid(.00001)
# Out:
# 0.5000024999999999

# %%
sigmoid(10000)
# Out:
# 1.0

# %%
sigmoid(-1)
# Out:
# 0.2689414213699951

# %%
sigmoid(-10)
# Out:
# 4.539786870243442e-05

# %%
sigmoid(-2.0)
# Out:
# 0.11920292202211757
